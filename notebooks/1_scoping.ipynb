# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from agent.src.utils.display import format_messages
from agent.src.utils.helper import get_today_str
from agent.src.subgraphs.scoping_graph import scope_research

# %%
# Instantiate compiled graph
scope = scope_research

# %%
# Run the workflow
from langchain_core.messages import HumanMessage
thread = {"configurable": {"thread_id": "1"}}
result = scope.invoke({"messages": [HumanMessage(content="I want to research the best coffee shops in San Francisco.")]}, config=thread)
format_messages(result['messages'])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ I want to research the best coffee shops in San Francisco.                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │ To provide the best recommendations, could you please clarify a few preferences? 1. Are you looking for         │
# │ specific neighborhoods in San Francisco? 2. Do you have a preference for the type of coffee shop (e.g.,         │
# │ specialty roasters, cozy spots for working, or places with food options)? 3. Are there any specific price       │
# │ ranges or amenities (like outdoor seating or Wi-Fi) that are important to you?                                  │
# ...

# %%
result = scope.invoke({"messages": [HumanMessage(content="My mistake i was asking for bhopal")]}, config=thread)
format_messages(result['messages'])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ My mistake i was asking for bhopal                                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │ To provide you with the most relevant report for Bhopal, could you please specify the topic or industry you are │
# │ interested in? For example, are you looking for information on economic development, tourism, real estate, or   │
# │ current events in the city?                                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# Run the workflow
from langchain_core.messages import HumanMessage
thread = {"configurable": {"thread_id": "1"}}
result = scope.invoke({"messages": [HumanMessage(content="I want to research the best coffee shops in Bhopal.")]}, config=thread)
format_messages(result['messages'])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ I want to research the best coffee shops in Bhopal.                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │ To provide you with the best recommendations, could you please clarify a few details: 1. Are you looking for    │
# │ specific types of coffee shops (e.g., quiet spots for working, trendy cafes for socializing, or places with     │
# │ specialty roasts)? 2. Do you have a preferred area or neighborhood in Bhopal, or should I look across the       │
# │ entire city?                                                                                                    │
# ...

# %%
result = scope.invoke({"messages": [HumanMessage(content="I want a quiet place with nice view and search across the entire city")]}, config=thread)
format_messages(result['messages'])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ I want to research the best coffee shops in Bhopal.                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │ To provide you with the best recommendations, could you please clarify a few details: 1. Are you looking for    │
# │ specific types of coffee shops (e.g., quiet spots for working, trendy cafes for socializing, or places with     │
# │ specialty roasts)? 2. Do you have a preferred area or neighborhood in Bhopal, or should I look across the       │
# │ entire city?                                                                                                    │
# ...

# %%
scope.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='I want to research the best coffee shops in Bhopal.', additional_kwargs={}, response_metadata={}, id='8e4e003b-893a-47bc-8ae1-4ae565e3fb8a'), AIMessage(content='To provide you with the best recommendations, could you please clarify a few details: 1. Are you looking for specific types of coffee shops (e.g., quiet spots for working, trendy cafes for socializing, or places with specialty roasts)? 2. Do you have a preferred area or neighborhood in Bhopal, or should I look across the entire city?', additional_kwargs={}, response_metadata={}, id='38dea188-1bf1-43c0-9d71-6cefec1e2d74', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='I want a quiet place with nice view and search across the entire city', additional_kwargs={}, response_metadata={}, id='3a43c3a0-b7c4-4f71-a1eb-98ec96996a35'), AIMessage(content='I have sufficient information to proceed. I will now research quiet coffee shops with nice views across Bhopal and 
# ...

# %%
from agent.src.utils.display import display_graph, save_graph_image

# Display directly inside Jupyter cell
display_graph(scope)
