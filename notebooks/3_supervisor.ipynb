# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
from agent.src.subgraphs.supervisor import supervisor_agent
from agent.src.utils.display import display_graph
from agent.src.utils.display import format_messages

# %%
# Initialize the supervisor agent
supervisor = supervisor_agent

# %%
# display the graph structure of the supervisor agent
display_graph(supervisor)

# %%
from langchain_core.messages import HumanMessage

# %%
research_brief = "Identify and evaluate the best coffee shops across Bhopal that offer a quiet atmosphere suitable for focused work or relaxation and feature a nice view. My research should prioritize venues that explicitly cater to a tranquil environment and aesthetic appeal. I have not specified a budget range, so please consider all price points. Please prioritize information from official cafe websites, verified social media pages, or reputable local business directories to ensure the accuracy of the atmosphere and view descriptions."

result = await supervisor_agent.ainvoke({"supervisor_messages": [HumanMessage(content=f"{research_brief}.")]})
format_messages(result['supervisor_messages'])
# Out:
# Error in supervisor tools: Error calling model 'gemini-3.6-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-3.6-flash\nPlease retry in 16.75236142s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.6-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '16s'}]}}
# ┌───────────────────────────────── 🧑 Human ──────────────────────────────────┐
# │ Identify and evaluate the best coffee shops across Bhopal that offer a      │
# │ quiet atmosphere suitable for focused work or relaxation and feature a nice │
# │ view. My research should prioritize venues that explicitly cater to a       │
# │ tranquil environment and aesthetic appeal. I have not specified a budget    │
# │ range, so please consider all price points. Please prioritize information   │
# │ from official cafe websites, verified social media pages, or reputable      │
# │ local business directories to ensure the accuracy of the atmosphere and     │
# │ view descriptions..                                                         │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────── 📝 AI ───────────────────────────────────┐
# │                                                                             │
# │ 🔧 Tool Call: think_tool                                                    │
# │    Args: {                                                                  │
# │   "reflection": "The user wants a list and detailed evaluation of the best  │
# │ coffee shops in Bhopal that satisfy two primary criteria:\n1. A quiet,      │
# │ peaceful atmosphere suitable for focused work or relaxation.\n2. A nice     │
# │ view / high aesthetic appeal (e.g., lake views, lush green gardens, stylish │
# │ serene interiors).\n\nTo ensure thorough coverage across different parts of │
# │ Bhopal (especially key scenic areas like Upper Lake/Shamla Hills/Shahpura   │
# │ Lake vs urban leafy hubs like Arera Colony/Gulmohar), I can divide the      │
# │ research into two parallel sub-topics:\nAgent 1: Research cafes/coffee      │
# │ shops around Upper Lake, VIP Road, Shamla Hills, and Shahpura Lake in       │
# │ Bhopal that offer serene lake views/scenic outlooks and a quiet,            │
# │ work/relaxation-friendly environment.\nAgent 2: Research top aesthetic,     │
# │ work-friendly, and quiet cafes/coffee shops in Arera Colony, Gulmohar, MP   │
# │ Nagar, and other central/southern areas of Bhopal known for tranquil        │
# │ interiors, garden views, and remote work friendliness.\n\nLet's verify what │
# │ specific cafes exist in these categories with detailed amenities, Wi-Fi     │
# │ availability, seating, views, price range, and customer reviews from        │
# │ reputable sources."                                                         │
# │ }                                                                           │
# │    ID: pDPPbW8f                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌────────────────────────────── 🔧 Tool Output ───────────────────────────────┐
# │ Reflection recorded: The user wants a list and detailed evaluation of the   │
# │ best coffee shops in Bhopal that satisfy two primary criteria:              │
# │ 1. A quiet, peaceful atmosphere suitable for focused work or relaxation.    │
# │ 2. A nice view / high aesthetic appeal (e.g., lake views, lush green        │
# │ gardens, stylish serene interiors).                                         │
# │                                                                             │
# │ To ensure thorough coverage across different parts of Bhopal (especially    │
# │ key scenic areas like Upper Lake/Shamla Hills/Shahpura Lake vs urban leafy  │
# │ hubs like Arera Colony/Gulmohar), I can divide the research into two        │
# │ parallel sub-topics:                                                        │
# │ Agent 1: Research cafes/coffee shops around Upper Lake, VIP Road, Shamla    │
# │ Hills, and Shahpura Lake in Bhopal that offer serene lake views/scenic      │
# │ outlooks and a quiet, work/relaxation-friendly environment.                 │
# │ Agent 2: Research top aesthetic, work-friendly, and quiet cafes/coffee      │
# │ shops in Arera Colony, Gulmohar, MP Nagar, and other central/southern areas │
# │ of Bhopal known for tranquil interiors, garden views, and remote work       │
# │ friendliness.                                                               │
# │                                                                             │
# │ Let's verify what specific cafes exist in these categories with detailed    │
# │ amenities, Wi-Fi availability, seating, views, price range, and customer    │
# │ reviews from reputable sources.                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────── 📝 AI ───────────────────────────────────┐
# │                                                                             │
# │ 🔧 Tool Call: ConductResearch                                               │
# │    Args: {                                                                  │
# │   "research_topic": "Research top coffee shops and cafes around Upper Lake, │
# │ Shamla Hills, VIP Road, and Shahpura Lake in Bhopal, India that offer       │
# │ scenic lake views or natural landscapes combined with a quiet, peaceful     │
# │ atmosphere suitable for focused work or relaxation. Find detailed           │
# │ information on: 1) Specific cafe names and exact locations, 2) Description  │
# │ of the view and aesthetic appeal, 3) Work suitability (noise levels, Wi-Fi, │
# │ power outlets, seating comfort), 4) Coffee/food menu quality and price      │
# │ point/range, 5) Operating hours and best time to visit for a tranquil       │
# │ experience. Verify details against official websites, social media pages,   │
# │ Zomato, Google Maps, or reputable travel/local guides."                     │
# │ }                                                                           │
# │    ID: 3EPwV6YE                                                             │
# │                                                                             │
# │ 🔧 Tool Call: ConductResearch                                               │
# │    Args: {                                                                  │
# │   "research_topic": "Research top coffee shops and cafes in Arera Colony,   │
# │ Gulmohar, Chunabhatti, E-8, and central neighborhoods of Bhopal, India that │
# │ are renowned for quiet, tranquil environments suitable for remote work or   │
# │ relaxation, alongside aesthetic appeal (such as garden views, courtyard     │
# │ seating, rooftop greenery, or serene minimalist design). Find detailed      │
# │ information on: 1) Specific cafe names and exact locations, 2)              │
# │ View/aesthetic highlights, 3) Work suitability features (Wi-Fi, quietness,  │
# │ power sockets, seating), 4) Menu offerings and price points, 5) Operating   │
# │ hours and peak/quiet hours. Verify details against official sources, social │
# │ media, and reputable local business reviews."                               │
# │ }                                                                           │
# │    ID: iIewum4V                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
